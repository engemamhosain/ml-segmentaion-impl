# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
import os

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from skimage.io import imread
from skimage.transform import resize
import keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate,Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Load the data ---

# Paths to the dataset
train_data_path = '/kaggle/input/final-augmented-dataset/aug-and-images-20240918T063356Z-001/aug-and-images'
train_mask_data_path = '/kaggle/input/final-augmented-dataset/aug-and-masks-20240918T063354Z-001/aug-and-masks'

# Load images and masks (limit to 100 for demonstration)
training_images = os.listdir(train_data_path)[0:1328]
training_masks = os.listdir(train_mask_data_path)[0:1328]

# Image dimensions
row, columns = 512, 512

# Initialize arrays for images and masks
x_train = np.zeros((len(training_images), row, columns, 3), dtype=np.uint8)
y_train = np.zeros((len(training_masks), row, columns, 3), dtype=np.uint8)

# Load and resize images and masks
for index, name in enumerate(training_images):
    img_path = os.path.join(train_data_path, name)
    mask_path = os.path.join(train_mask_data_path, name)
    
    if os.path.exists(mask_path):
        image = imread(img_path)
        mask = imread(mask_path)
#         mask = (mask > 0.5).astype(np.float32)
        
        # Expand mask dimensions from (512, 512) to (512, 512, 1)
#         mask = np.expand_dims(mask, axis=-1)
        
        x_train[index] = image
        y_train[index] = mask

# %%
x_train = x_train.astype('float32') / 255.0
y_train = y_train.astype('float32') / 255.0
# y_train = y_train.astype(np.float32)
y_train = (y_train > .5).astype(np.float32)

# %%
import matplotlib.pyplot as plt

# Plot the first image from x_train
plt.figure(figsize=(15, 5))  # Set figure size to display all images properly
index=8
plt.subplot(1, 4, 1)  # (1 row, 3 columns, first subplot)
plt.imshow(x_train[index])
plt.title('total_x_train')
plt.axis('off')  # Hide axes

# Plot the first image from augmented_masks
plt.subplot(1, 4, 2)  # (1 row, 3 columns, third subplot)
plt.imshow(y_train[index])
plt.title('total_y_train')
plt.axis('off')

# Display the images
plt.show()

# %%
import tensorflow.keras.backend as K

def dice_coef(a, b):

    hi = a
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    upper_part = 2 * K.sum((hi * pred))
    lower_part = K.sum(hi + pred)
    dice = upper_part / lower_part
    return dice

def dice_coef_loss(a, b):
    loss = 1 - dice_coef(a, b)
    return loss

def jaccard_index(a, b):
    hi = a 
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    numerator = K.sum(hi * pred)
    denominator = K.sum((hi + pred) - (hi * pred))
    iou = numerator / denominator
    return iou

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

def termina_net(input_shape=(512, 512, 3)):  # Change input shape to (512, 512, 3)
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c9)

    outputs = layers.Conv2D(3, (1, 1), activation='sigmoid')(c9)  # Output layer for binary segmentation

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# # Create the model
# input_shape = (512, 512, 3)  # Update to RGB input
# model = termina_net(input_shape)

# # Compile the model
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# # Model summary
# model.summary()

# %%
# # Create the model
input_shape = (512, 512, 3)  # Update to RGB input
model = termina_net(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy',  metrics=[dice_coef, jaccard_index])

# Model summary
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 512, 512,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 512, 512,  │      9,248 │ conv2d_19[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 256, 256,  │          0 │ conv2d_20[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 256, 256,  │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_21[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 128, 128,  │          0 │ conv2d_22[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │     73,856 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_23[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 64, 64,    │          0 │ conv2d_24[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 64, 64,    │    295,168 │ max_pooling2d_6[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_25[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 32, 32,    │          0 │ conv2d_26[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_7[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_27[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 64, 64,    │    524,544 │ conv2d_28[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_4[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_29[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 128, 128,  │    131,200 │ conv2d_30[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_31[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 256, 256,  │     32,832 │ conv2d_32[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 512, 512,  │      8,224 │ conv2d_34[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 512, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 512, 512,  │     18,464 │ concatenate_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 512, 512,  │      9,248 │ conv2d_35[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 512, 512,  │         99 │ conv2d_36[0][0]   │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,760,163 (29.60 MB)
#  Trainable params: 7,760,163 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
earlystopper = EarlyStopping(patience=5, verbose=1)

checkpoint = ModelCheckpoint('model.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min' )
#mode='min'
#earlystopper,
history = model.fit(x_train[10:], y_train[10:], validation_split=0.2, batch_size=1, epochs=20,callbacks=[earlystopper, checkpoint])
# Out:
# Epoch 1/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.6209 - jaccard_index: 0.5068 - loss: 0.2858
# Epoch 1: val_loss improved from inf to 0.13750, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 63s 51ms/step - dice_coef: 0.6211 - jaccard_index: 0.5070 - loss: 0.2857 - val_dice_coef: 0.7764 - val_jaccard_index: 0.6842 - val_loss: 0.1375
# Epoch 2/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.7688 - jaccard_index: 0.6698 - loss: 0.1661
# Epoch 2: val_loss did not improve from 0.13750
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.7688 - jaccard_index: 0.6698 - loss: 0.1661 - val_dice_coef: 0.7746 - val_jaccard_index: 0.6849 - val_loss: 0.1462
# Epoch 3/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.7664 - jaccard_index: 0.6709 - loss: 0.1534
# Epoch 3: val_loss improved from 0.13750 to 0.13226, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.7664 - jaccard_index: 0.6710 - loss: 0.1534 - val_dice_coef: 0.7950 - val_jaccard_index: 0.7161 - val_loss: 0.1323
# Epoch 4/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.7525 - jaccard_index: 0.6586 - loss: 0.1555
# Epoch 4: val_loss improved from 0.13226 to 0.08839, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.7526 - jaccard_index: 0.6587 - loss: 0.1554 - val_dice_coef: 0.8195 - val_jaccard_index: 0.7506 - val_loss: 0.0884
# Epoch 5/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8303 - jaccard_index: 0.7531 - loss: 0.1106
# Epoch 5: val_loss did not improve from 0.08839
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8303 - jaccard_index: 0.7531 - loss: 0.1106 - val_dice_coef: 0.7965 - val_jaccard_index: 0.7148 - val_loss: 0.1109
# Epoch 6/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8313 - jaccard_index: 0.7640 - loss: 0.0890
# Epoch 6: val_loss did not improve from 0.08839
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8313 - jaccard_index: 0.7640 - loss: 0.0890 - val_dice_coef: 0.7967 - val_jaccard_index: 0.7128 - val_loss: 0.0976
# Epoch 7/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8263 - jaccard_index: 0.7527 - loss: 0.1116
# Epoch 7: val_loss improved from 0.08839 to 0.07943, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.8263 - jaccard_index: 0.7527 - loss: 0.1116 - val_dice_coef: 0.8323 - val_jaccard_index: 0.7716 - val_loss: 0.0794
# Epoch 8/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8394 - jaccard_index: 0.7781 - loss: 0.0794
# Epoch 8: val_loss improved from 0.07943 to 0.06794, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.8394 - jaccard_index: 0.7781 - loss: 0.0794 - val_dice_coef: 0.8417 - val_jaccard_index: 0.7876 - val_loss: 0.0679
# Epoch 9/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8414 - jaccard_index: 0.7825 - loss: 0.0740
# Epoch 9: val_loss did not improve from 0.06794
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8414 - jaccard_index: 0.7825 - loss: 0.0740 - val_dice_coef: 0.8111 - val_jaccard_index: 0.7376 - val_loss: 0.0976
# Epoch 10/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8360 - jaccard_index: 0.7740 - loss: 0.0806
# Epoch 10: val_loss did not improve from 0.06794
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8360 - jaccard_index: 0.7740 - loss: 0.0806 - val_dice_coef: 0.8392 - val_jaccard_index: 0.7834 - val_loss: 0.0689
# Epoch 11/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8546 - jaccard_index: 0.7936 - loss: 0.0802
# Epoch 11: val_loss improved from 0.06794 to 0.06586, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.8546 - jaccard_index: 0.7936 - loss: 0.0802 - val_dice_coef: 0.8436 - val_jaccard_index: 0.7909 - val_loss: 0.0659
# Epoch 12/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8550 - jaccard_index: 0.7994 - loss: 0.0706
# Epoch 12: val_loss improved from 0.06586 to 0.06477, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.8549 - jaccard_index: 0.7994 - loss: 0.0706 - val_dice_coef: 0.8389 - val_jaccard_index: 0.7830 - val_loss: 0.0648
# Epoch 13/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8523 - jaccard_index: 0.7966 - loss: 0.0725
# Epoch 13: val_loss improved from 0.06477 to 0.06228, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8523 - jaccard_index: 0.7966 - loss: 0.0725 - val_dice_coef: 0.8359 - val_jaccard_index: 0.7773 - val_loss: 0.0623
# Epoch 14/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8596 - jaccard_index: 0.8053 - loss: 0.0670
# Epoch 14: val_loss did not improve from 0.06228
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8596 - jaccard_index: 0.8053 - loss: 0.0670 - val_dice_coef: 0.8395 - val_jaccard_index: 0.7838 - val_loss: 0.0651
# Epoch 15/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8637 - jaccard_index: 0.8091 - loss: 0.0678
# Epoch 15: val_loss improved from 0.06228 to 0.06119, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.8636 - jaccard_index: 0.8091 - loss: 0.0678 - val_dice_coef: 0.8506 - val_jaccard_index: 0.8028 - val_loss: 0.0612
# Epoch 16/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8519 - jaccard_index: 0.7979 - loss: 0.0676
# Epoch 16: val_loss did not improve from 0.06119
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8519 - jaccard_index: 0.7979 - loss: 0.0676 - val_dice_coef: 0.8417 - val_jaccard_index: 0.7881 - val_loss: 0.0730
# Epoch 17/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8521 - jaccard_index: 0.7976 - loss: 0.0694
# Epoch 17: val_loss did not improve from 0.06119
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8521 - jaccard_index: 0.7976 - loss: 0.0694 - val_dice_coef: 0.8410 - val_jaccard_index: 0.7867 - val_loss: 0.0773
# Epoch 18/20
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8543 - jaccard_index: 0.7984 - loss: 0.0697
# Epoch 18: val_loss did not improve from 0.06119
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8543 - jaccard_index: 0.7984 - loss: 0.0697 - val_dice_coef: 0.8474 - val_jaccard_index: 0.7972 - val_loss: 0.0630
# Epoch 19/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8671 - jaccard_index: 0.8152 - loss: 0.0652
# Epoch 19: val_loss did not improve from 0.06119
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 46ms/step - dice_coef: 0.8670 - jaccard_index: 0.8152 - loss: 0.0652 - val_dice_coef: 0.8309 - val_jaccard_index: 0.7693 - val_loss: 0.0681
# Epoch 20/20
# 1053/1054 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dice_coef: 0.8648 - jaccard_index: 0.8100 - loss: 0.0677
# Epoch 20: val_loss improved from 0.06119 to 0.05786, saving model to model.keras
# 1054/1054 ━━━━━━━━━━━━━━━━━━━━ 49s 47ms/step - dice_coef: 0.8648 - jaccard_index: 0.8100 - loss: 0.0677 - val_dice_coef: 0.8497 - val_jaccard_index: 0.8013 - val_loss: 0.0579

# %%
pred = model.predict(x_train[2:3])
pred = np.squeeze(pred)
plt.imshow(pred, cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step

# %%
# Plot the first image from x_train
plt.figure(figsize=(15, 5))  # Set figure size to display all images properly
index=8
plt.subplot(1, 4, 1)  # (1 row, 3 columns, first subplot)
plt.imshow(np.squeeze(x_train[2:3]))
plt.title('x_train')
plt.axis('off')  # Hide axes

# Plot the first image from augmented_masks
plt.subplot(1, 4, 2)  # (1 row, 3 columns, third subplot)
plt.imshow(pred)
plt.title('pred of y_train')
plt.axis('off')

# Plot the first image from augmented_masks
plt.subplot(1, 4, 3)  # (1 row, 3 columns, third subplot)
plt.imshow(np.squeeze(y_train[2:3]))
plt.title('y_train')
plt.axis('off')

# Display the images
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Binary_crossEntropy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice coeff')
plt.ylabel('Dice coeff')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['jaccard_index'])
plt.plot(history.history['val_jaccard_index'])
plt.title('Model jaccard index')
plt.ylabel('Jaccard index')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
