# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from skimage.io import imread
from skimage.transform import resize
import keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate,Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# --- Load the data ---

# Paths to the dataset
train_data_path = '/kaggle/input/final-augmented-dataset/aug-and-images-20240918T063356Z-001/aug-and-images'
train_mask_data_path = '/kaggle/input/final-augmented-dataset/aug-and-masks-20240918T063354Z-001/aug-and-masks'

# Load images and masks (limit to 100 for demonstration)
training_images = os.listdir(train_data_path)[0:1328]
training_masks = os.listdir(train_mask_data_path)[0:1328]

# Image dimensions
row, columns = 512, 512

# Initialize arrays for images and masks
x_train = np.zeros((len(training_images), row, columns, 3), dtype=np.uint8)
y_train = np.zeros((len(training_masks), row, columns, 3), dtype=np.uint8)

# Load and resize images and masks
for index, name in enumerate(training_images):
    img_path = os.path.join(train_data_path, name)
    mask_path = os.path.join(train_mask_data_path, name)
    
    if os.path.exists(mask_path):
        image = imread(img_path)
        mask = imread(mask_path)
#         mask = (mask > 0.5).astype(np.float32)
        
        # Expand mask dimensions from (512, 512) to (512, 512, 1)
#         mask = np.expand_dims(mask, axis=-1)
        
        x_train[index] = image
        y_train[index] = mask

# %%
x_train = x_train.astype('float32') / 255.0
y_train = y_train.astype('float32') / 255.0
# y_train = y_train.astype(np.float32)
y_train = (y_train > .5).astype(np.float32)

# %%
import matplotlib.pyplot as plt

# Plot the first image from x_train
plt.figure(figsize=(15, 5))  # Set figure size to display all images properly
index=8
plt.subplot(1, 4, 1)  # (1 row, 3 columns, first subplot)
plt.imshow(x_train[index])
plt.title('total_x_train')
plt.axis('off')  # Hide axes

# Plot the first image from augmented_masks
plt.subplot(1, 4, 2)  # (1 row, 3 columns, third subplot)
plt.imshow(y_train[index])
plt.title('total_y_train')
plt.axis('off')

# Display the images
plt.show()

# %%
import tensorflow.keras.backend as K

def dice_coef(a, b):

    hi = a
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    upper_part = 2 * K.sum((hi * pred))
    lower_part = K.sum(hi + pred)
    dice = upper_part / lower_part
    return dice

def dice_coef_loss(a, b):
    loss = 1 - dice_coef(a, b)
    return loss

def jaccard_index(a, b):
    hi = a 
    pred = b
    hi = K.flatten(hi)
    pred = K.flatten(pred)
    numerator = K.sum(hi * pred)
    denominator = K.sum((hi + pred) - (hi * pred))
    iou = numerator / denominator
    return iou

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# --- Define the FCN Model ---

def build_fcn(input_shape=(512, 512, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # Convolutional Block 1
    c1 = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(inputs)
    c1 = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    # Convolutional Block 2
    c2 = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(p1)
    c2 = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    # Convolutional Block 3
    c3 = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(p2)
    c3 = layers.Conv2D(256, (3, 3), padding='same', activation='relu')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    # Convolutional Block 4
    c4 = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(p3)
    c4 = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Convolutional Block 5
    c5 = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(p4)
    c5 = layers.Conv2D(512, (3, 3), padding='same', activation='relu')(c5)

    # Fully Convolutional Layers
    fcn = layers.Conv2D(num_classes, (1, 1), padding='same')(c5)
    fcn = layers.UpSampling2D(size=(2, 2))(fcn)
    fcn = layers.Conv2D(num_classes, (1, 1), padding='same')(fcn)

    fcn = layers.UpSampling2D(size=(2, 2))(fcn)
    fcn = layers.Conv2D(num_classes, (1, 1), padding='same')(fcn)

    fcn = layers.UpSampling2D(size=(2, 2))(fcn)
    fcn = layers.Conv2D(num_classes, (1, 1), padding='same')(fcn)

    fcn = layers.UpSampling2D(size=(2, 2))(fcn)
    fcn = layers.Conv2D(3, (1, 1), padding='same')(fcn)

    outputs = layers.Activation('sigmoid')(fcn)  # Sigmoid for binary segmentation

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Create the model
model = build_fcn(input_shape=(512, 512, 3), num_classes=1)
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
# Compile the model
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[dice_coef,jaccard_index])

# Show model summary
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 512, 512, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 512, 512, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 512, 512, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 256, 256, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 256, 256, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 128, 128, 256)  │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 128, 128, 256)  │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 64, 64, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 64, 64, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 32, 32, 1)      │           513 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_8 (UpSampling2D)  │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 64, 64, 1)      │             2 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_9 (UpSampling2D)  │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 128, 128, 1)    │             2 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_10 (UpSampling2D) │ (None, 256, 256, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 256, 256, 1)    │             2 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_11 (UpSampling2D) │ (None, 512, 512, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 512, 512, 3)    │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 512, 512, 3)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,405,517 (35.88 MB)
#  Trainable params: 9,405,517 (35.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# --- Train the Model ---
checkpoint = ModelCheckpoint('fcn_model.keras', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
earlystopper = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')

# Fit the model
history = model.fit(x_train, y_train, validation_split=0.2, batch_size=1, epochs=20, callbacks=[checkpoint, earlystopper])
# Out:
# Epoch 1/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.3365 - jaccard_index: 0.2090 - loss: 0.6741
# Epoch 1: val_loss improved from inf to 0.62790, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 55s 46ms/step - dice_coef: 0.3365 - jaccard_index: 0.2090 - loss: 0.6740 - val_dice_coef: 0.3525 - val_jaccard_index: 0.2219 - val_loss: 0.6279
# Epoch 2/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.3586 - jaccard_index: 0.2257 - loss: 0.6108
# Epoch 2: val_loss improved from 0.62790 to 0.55168, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 42ms/step - dice_coef: 0.3587 - jaccard_index: 0.2258 - loss: 0.6107 - val_dice_coef: 0.3882 - val_jaccard_index: 0.2502 - val_loss: 0.5517
# Epoch 3/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.3950 - jaccard_index: 0.2558 - loss: 0.5280
# Epoch 3: val_loss improved from 0.55168 to 0.43298, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 42ms/step - dice_coef: 0.3950 - jaccard_index: 0.2559 - loss: 0.5280 - val_dice_coef: 0.4580 - val_jaccard_index: 0.3094 - val_loss: 0.4330
# Epoch 4/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.5281 - jaccard_index: 0.3725 - loss: 0.3885
# Epoch 4: val_loss improved from 0.43298 to 0.26660, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 42ms/step - dice_coef: 0.5282 - jaccard_index: 0.3726 - loss: 0.3884 - val_dice_coef: 0.6110 - val_jaccard_index: 0.4617 - val_loss: 0.2666
# Epoch 5/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6154 - jaccard_index: 0.4625 - loss: 0.2680
# Epoch 5: val_loss improved from 0.26660 to 0.24739, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 42ms/step - dice_coef: 0.6154 - jaccard_index: 0.4625 - loss: 0.2680 - val_dice_coef: 0.6236 - val_jaccard_index: 0.4761 - val_loss: 0.2474
# Epoch 6/20
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6303 - jaccard_index: 0.4795 - loss: 0.2562
# Epoch 6: val_loss did not improve from 0.24739
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 42ms/step - dice_coef: 0.6303 - jaccard_index: 0.4795 - loss: 0.2562 - val_dice_coef: 0.6204 - val_jaccard_index: 0.4727 - val_loss: 0.2506
# Epoch 7/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6311 - jaccard_index: 0.4834 - loss: 0.2504
# Epoch 7: val_loss improved from 0.24739 to 0.23196, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 42ms/step - dice_coef: 0.6311 - jaccard_index: 0.4834 - loss: 0.2504 - val_dice_coef: 0.6357 - val_jaccard_index: 0.4901 - val_loss: 0.2320
# Epoch 8/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6461 - jaccard_index: 0.5010 - loss: 0.2372
# Epoch 8: val_loss improved from 0.23196 to 0.22608, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 43ms/step - dice_coef: 0.6462 - jaccard_index: 0.5010 - loss: 0.2372 - val_dice_coef: 0.6556 - val_jaccard_index: 0.5141 - val_loss: 0.2261
# Epoch 9/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6582 - jaccard_index: 0.5134 - loss: 0.2348
# Epoch 9: val_loss improved from 0.22608 to 0.21851, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 43ms/step - dice_coef: 0.6582 - jaccard_index: 0.5134 - loss: 0.2348 - val_dice_coef: 0.6699 - val_jaccard_index: 0.5320 - val_loss: 0.2185
# Epoch 10/20
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6660 - jaccard_index: 0.5231 - loss: 0.2218
# Epoch 10: val_loss improved from 0.21851 to 0.21341, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 43ms/step - dice_coef: 0.6660 - jaccard_index: 0.5231 - loss: 0.2218 - val_dice_coef: 0.6669 - val_jaccard_index: 0.5283 - val_loss: 0.2134
# Epoch 11/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6719 - jaccard_index: 0.5296 - loss: 0.2223
# Epoch 11: val_loss improved from 0.21341 to 0.20934, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 43ms/step - dice_coef: 0.6719 - jaccard_index: 0.5296 - loss: 0.2223 - val_dice_coef: 0.6719 - val_jaccard_index: 0.5345 - val_loss: 0.2093
# Epoch 12/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6675 - jaccard_index: 0.5296 - loss: 0.2125
# Epoch 12: val_loss improved from 0.20934 to 0.20747, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 43ms/step - dice_coef: 0.6675 - jaccard_index: 0.5296 - loss: 0.2125 - val_dice_coef: 0.6684 - val_jaccard_index: 0.5300 - val_loss: 0.2075
# Epoch 13/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6699 - jaccard_index: 0.5321 - loss: 0.2097
# Epoch 13: val_loss improved from 0.20747 to 0.20554, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 43ms/step - dice_coef: 0.6699 - jaccard_index: 0.5321 - loss: 0.2097 - val_dice_coef: 0.6754 - val_jaccard_index: 0.5389 - val_loss: 0.2055
# Epoch 14/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6840 - jaccard_index: 0.5455 - loss: 0.2109
# Epoch 14: val_loss did not improve from 0.20554
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 41ms/step - dice_coef: 0.6840 - jaccard_index: 0.5455 - loss: 0.2109 - val_dice_coef: 0.6701 - val_jaccard_index: 0.5324 - val_loss: 0.2077
# Epoch 15/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.6903 - jaccard_index: 0.5489 - loss: 0.2144
# Epoch 15: val_loss did not improve from 0.20554
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 41ms/step - dice_coef: 0.6903 - jaccard_index: 0.5489 - loss: 0.2144 - val_dice_coef: 0.6822 - val_jaccard_index: 0.5477 - val_loss: 0.2066
# Epoch 16/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.6872 - jaccard_index: 0.5484 - loss: 0.2073
# Epoch 16: val_loss improved from 0.20554 to 0.20325, saving model to fcn_model.keras
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 41ms/step - dice_coef: 0.6872 - jaccard_index: 0.5484 - loss: 0.2073 - val_dice_coef: 0.6763 - val_jaccard_index: 0.5401 - val_loss: 0.2033
# Epoch 17/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.6777 - jaccard_index: 0.5414 - loss: 0.2057
# Epoch 17: val_loss did not improve from 0.20325
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 41ms/step - dice_coef: 0.6777 - jaccard_index: 0.5414 - loss: 0.2057 - val_dice_coef: 0.6744 - val_jaccard_index: 0.5378 - val_loss: 0.2061
# Epoch 18/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coef: 0.6918 - jaccard_index: 0.5526 - loss: 0.2092
# Epoch 18: val_loss did not improve from 0.20325
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 41ms/step - dice_coef: 0.6918 - jaccard_index: 0.5526 - loss: 0.2092 - val_dice_coef: 0.6744 - val_jaccard_index: 0.5377 - val_loss: 0.2051
# Epoch 19/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6842 - jaccard_index: 0.5449 - loss: 0.2184
# Epoch 19: val_loss did not improve from 0.20325
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 44s 42ms/step - dice_coef: 0.6842 - jaccard_index: 0.5449 - loss: 0.2184 - val_dice_coef: 0.6828 - val_jaccard_index: 0.5484 - val_loss: 0.2040
# Epoch 20/20
# 1061/1062 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.6938 - jaccard_index: 0.5549 - loss: 0.2071
# Epoch 20: val_loss did not improve from 0.20325
# 1062/1062 ━━━━━━━━━━━━━━━━━━━━ 45s 42ms/step - dice_coef: 0.6938 - jaccard_index: 0.5549 - loss: 0.2071 - val_dice_coef: 0.6752 - val_jaccard_index: 0.5387 - val_loss: 0.2042

# %%
pred = model.predict(x_train[2:3])
pred = np.squeeze(pred)
plt.imshow(pred, cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step

# %%
# Plot the first image from x_train
plt.figure(figsize=(15, 5))  # Set figure size to display all images properly
index=8
plt.subplot(1, 4, 1)  # (1 row, 3 columns, first subplot)
plt.imshow(np.squeeze(x_train[2:3]))
plt.title('x_train')
plt.axis('off')  # Hide axes

# Plot the first image from augmented_masks
plt.subplot(1, 4, 2)  # (1 row, 3 columns, third subplot)
plt.imshow(pred)
plt.title('pred of y_train')
plt.axis('off')

# Plot the first image from augmented_masks
plt.subplot(1, 4, 3)  # (1 row, 3 columns, third subplot)
plt.imshow(np.squeeze(y_train[2:3]))
plt.title('y_train')
plt.axis('off')

# Display the images
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Binary_crossEntropy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Model dice coeff')
plt.ylabel('Dice coeff')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['jaccard_index'])
plt.plot(history.history['val_jaccard_index'])
plt.title('Model jaccard index')
plt.ylabel('Jaccard index')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
